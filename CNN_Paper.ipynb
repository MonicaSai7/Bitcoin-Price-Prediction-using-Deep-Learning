# %%
import pandas as pd
import numpy as numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU, PReLU
from keras.utils import np_utils
from keras.callbacks import CSVLogger, ModelCheckpoint
import h5py
import os
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
# Use CNN to capture local temporal dependency of data in risk prediction or other related tasks.
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config))

# %%
with h5py.File(''.join(['data/bitcoin2015to2019_close.h5']), 'r') as hf:
    datas = hf['inputs'].value
    labels = hf['outputs'].value

# %%
output_file_name='bitcoin2015to2019_close_CNN_2_relu'

# %%
step_size = datas.shape[1]
batch_size= 8
nb_features = datas.shape[2]

# %%
epochs = 100

# %%
#split training validation
training_size = int(0.8* datas.shape[0])
training_datas = datas[:training_size,:]
training_labels = labels[:training_size,:]
validation_datas = datas[training_size:,:]
validation_labels = labels[training_size:,:]

# %%
model = Sequential()
model.add(Conv1D(activation='relu',
input_shape=(step_size, nb_features), strides=3,
filters=8, kernel_size=8))
model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2,
filters=8, kernel_size=8))
model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(strides=2, filters=nb_features,
kernel_size=8))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1019 21:49:04.740129 13624 deprecation_wrapper.py:119] From C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1019 21:49:04.744119 13624 deprecation_wrapper.py:119] From C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1019 21:49:04.752098 13624 deprecation_wrapper.py:119] From C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1019 21:49:04.826897 13624 deprecation_wrapper.py:119] From C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W1019 21:49:04.854825 13624 deprecation.py:506] From C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.compile(loss='mse', optimizer='adam')
model.fit(training_datas, training_labels, verbose=1, batch_size=batch_size, validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True), ModelCheckpoint('weights_paper/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])
# Out:
# Train on 58 samples, validate on 15 samples
# Epoch 1/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0880 - val_loss: 0.1367
#
# Epoch 00001: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-01-0.13667.hdf5
# Epoch 2/100
# 58/58 [==============================] - 0s 894us/step - loss: 0.0668 - val_loss: 0.0980
#
# Epoch 00002: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-02-0.09801.hdf5
# Epoch 3/100
# 58/58 [==============================] - 0s 860us/step - loss: 0.0492 - val_loss: 0.0692
#
# Epoch 00003: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-03-0.06917.hdf5
# Epoch 4/100
# 58/58 [==============================] - 0s 894us/step - loss: 0.0407 - val_loss: 0.0486
#
# Epoch 00004: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-04-0.04862.hdf5
# Epoch 5/100
# 58/58 [==============================] - 0s 767us/step - loss: 0.0322 - val_loss: 0.0351
#
# Epoch 00005: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-05-0.03512.hdf5
# Epoch 6/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0253 - val_loss: 0.0248
#
# Epoch 00006: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-06-0.02485.hdf5
# Epoch 7/100
# 58/58 [==============================] - 0s 774us/step - loss: 0.0229 - val_loss: 0.0182
#
# Epoch 00007: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-07-0.01824.hdf5
# Epoch 8/100
# 58/58 [==============================] - 0s 860us/step - loss: 0.0205 - val_loss: 0.0175
#
# Epoch 00008: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-08-0.01751.hdf5
# Epoch 9/100
# 58/58 [==============================] - 0s 825us/step - loss: 0.0202 - val_loss: 0.0168
#
# Epoch 00009: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-09-0.01676.hdf5
# Epoch 10/100
# 58/58 [==============================] - 0s 929us/step - loss: 0.0185 - val_loss: 0.0173
#
# Epoch 00010: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-10-0.01730.hdf5
# Epoch 11/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0171 - val_loss: 0.0177
#
# Epoch 00011: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-11-0.01773.hdf5
# Epoch 12/100
# 58/58 [==============================] - 0s 963us/step - loss: 0.0147 - val_loss: 0.0145
#
# Epoch 00012: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-12-0.01455.hdf5
# Epoch 13/100
# 58/58 [==============================] - 0s 980us/step - loss: 0.0131 - val_loss: 0.0099
#
# Epoch 00013: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-13-0.00987.hdf5
# Epoch 14/100
# 58/58 [==============================] - 0s 904us/step - loss: 0.0127 - val_loss: 0.0086
#
# Epoch 00014: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-14-0.00858.hdf5
# Epoch 15/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0096
#
# Epoch 00015: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-15-0.00965.hdf5
# Epoch 16/100
# 58/58 [==============================] - 0s 929us/step - loss: 0.0125 - val_loss: 0.0106
#
# Epoch 00016: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-16-0.01061.hdf5
# Epoch 17/100
# 58/58 [==============================] - 0s 963us/step - loss: 0.0125 - val_loss: 0.0087
#
# Epoch 00017: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-17-0.00875.hdf5
# Epoch 18/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0098
#
# Epoch 00018: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-18-0.00980.hdf5
# Epoch 19/100
# 58/58 [==============================] - 0s 894us/step - loss: 0.0106 - val_loss: 0.0083
#
# Epoch 00019: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-19-0.00833.hdf5
# Epoch 20/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0107 - val_loss: 0.0070
#
# Epoch 00020: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-20-0.00698.hdf5
# Epoch 21/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0067
#
# Epoch 00021: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-21-0.00668.hdf5
# Epoch 22/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0080 - val_loss: 0.0069
#
# Epoch 00022: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-22-0.00694.hdf5
# Epoch 23/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0106 - val_loss: 0.0065
#
# Epoch 00023: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-23-0.00651.hdf5
# Epoch 24/100
# 58/58 [==============================] - 0s 929us/step - loss: 0.0097 - val_loss: 0.0088
#
# Epoch 00024: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-24-0.00878.hdf5
# Epoch 25/100
# 58/58 [==============================] - 0s 808us/step - loss: 0.0093 - val_loss: 0.0073
#
# Epoch 00025: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-25-0.00733.hdf5
# Epoch 26/100
# 58/58 [==============================] - 0s 784us/step - loss: 0.0146 - val_loss: 0.0080
#
# Epoch 00026: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-26-0.00795.hdf5
# Epoch 27/100
# 58/58 [==============================] - 0s 756us/step - loss: 0.0086 - val_loss: 0.0101
#
# Epoch 00027: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-27-0.01012.hdf5
# Epoch 28/100
# 58/58 [==============================] - 0s 860us/step - loss: 0.0085 - val_loss: 0.0082
#
# Epoch 00028: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-28-0.00823.hdf5
# Epoch 29/100
# 58/58 [==============================] - 0s 843us/step - loss: 0.0096 - val_loss: 0.0103
#
# Epoch 00029: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-29-0.01030.hdf5
# Epoch 30/100
# 58/58 [==============================] - 0s 945us/step - loss: 0.0085 - val_loss: 0.0110
#
# Epoch 00030: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-30-0.01103.hdf5
# Epoch 31/100
# 58/58 [==============================] - 0s 783us/step - loss: 0.0068 - val_loss: 0.0082
#
# Epoch 00031: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-31-0.00818.hdf5
# Epoch 32/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0095 - val_loss: 0.0085
#
# Epoch 00032: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-32-0.00851.hdf5
# Epoch 33/100
# 58/58 [==============================] - 0s 825us/step - loss: 0.0093 - val_loss: 0.0099
#
# Epoch 00033: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-33-0.00985.hdf5
# Epoch 34/100
# 58/58 [==============================] - 0s 860us/step - loss: 0.0078 - val_loss: 0.0056
#
# Epoch 00034: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-34-0.00562.hdf5
# Epoch 35/100
# 58/58 [==============================] - 0s 825us/step - loss: 0.0081 - val_loss: 0.0074
#
# Epoch 00035: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-35-0.00745.hdf5
# Epoch 36/100
# 58/58 [==============================] - 0s 825us/step - loss: 0.0106 - val_loss: 0.0081
#
# Epoch 00036: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-36-0.00806.hdf5
# Epoch 37/100
# 58/58 [==============================] - 0s 877us/step - loss: 0.0075 - val_loss: 0.0066
#
# Epoch 00037: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-37-0.00659.hdf5
# Epoch 38/100
# 58/58 [==============================] - 0s 825us/step - loss: 0.0082 - val_loss: 0.0058
#
# Epoch 00038: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-38-0.00580.hdf5
# Epoch 39/100
# 58/58 [==============================] - 0s 757us/step - loss: 0.0087 - val_loss: 0.0065
#
# Epoch 00039: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-39-0.00645.hdf5
# Epoch 40/100
# 58/58 [==============================] - 0s 998us/step - loss: 0.0073 - val_loss: 0.0065
#
# Epoch 00040: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-40-0.00651.hdf5
# Epoch 41/100
# 58/58 [==============================] - 0s 791us/step - loss: 0.0090 - val_loss: 0.0106
#
# Epoch 00041: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-41-0.01064.hdf5
# Epoch 42/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0082 - val_loss: 0.0058
# Epoch 00042: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-42-0.00584.hdf5
# Epoch 43/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0092 - val_loss: 0.0065
#
# Epoch 00043: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-43-0.00651.hdf5
# Epoch 44/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0086 - val_loss: 0.0058
#
# Epoch 00044: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-44-0.00576.hdf5
# Epoch 45/100
# 58/58 [==============================] - 0s 911us/step - loss: 0.0083 - val_loss: 0.0045
#
# Epoch 00045: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-45-0.00453.hdf5
# Epoch 46/100
# 58/58 [==============================] - 0s 963us/step - loss: 0.0072 - val_loss: 0.0074
#
# Epoch 00046: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-46-0.00739.hdf5
# Epoch 47/100
# 58/58 [==============================] - 0s 894us/step - loss: 0.0076 - val_loss: 0.0083
#
# Epoch 00047: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-47-0.00829.hdf5
# Epoch 48/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0080 - val_loss: 0.0113
#
# Epoch 00048: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-48-0.01127.hdf5
# Epoch 49/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0087 - val_loss: 0.0080
#
# Epoch 00049: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-49-0.00803.hdf5
# Epoch 50/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0082 - val_loss: 0.0060
#
# Epoch 00050: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-50-0.00596.hdf5
# Epoch 51/100
# 58/58 [==============================] - 0s 997us/step - loss: 0.0080 - val_loss: 0.0113
#
# Epoch 00051: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-51-0.01131.hdf5
# Epoch 52/100
# 58/58 [==============================] - 0s 980us/step - loss: 0.0068 - val_loss: 0.0074
#
# Epoch 00052: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-52-0.00743.hdf5
# Epoch 53/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0067 - val_loss: 0.0046
#
# Epoch 00053: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-53-0.00463.hdf5
# Epoch 54/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0082 - val_loss: 0.0063
#
# Epoch 00054: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-54-0.00625.hdf5
# Epoch 55/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0087 - val_loss: 0.0082
#
# Epoch 00055: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-55-0.00821.hdf5
# Epoch 56/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0085
#
# Epoch 00056: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-56-0.00848.hdf5
# Epoch 57/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0087 - val_loss: 0.0049
#
# Epoch 00057: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-57-0.00487.hdf5
# Epoch 58/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0102 - val_loss: 0.0056
#
# Epoch 00058: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-58-0.00564.hdf5
# Epoch 59/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0073 - val_loss: 0.0100
#
# Epoch 00059: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-59-0.01002.hdf5
# Epoch 60/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0078 - val_loss: 0.0065
#
# Epoch 00060: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-60-0.00646.hdf5
# Epoch 61/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0081 - val_loss: 0.0057
#
# Epoch 00061: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-61-0.00573.hdf5
# Epoch 62/100
# 58/58 [==============================] - 0s 877us/step - loss: 0.0088 - val_loss: 0.0114
#
# Epoch 00062: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-62-0.01140.hdf5
# Epoch 63/100
# 58/58 [==============================] - 0s 877us/step - loss: 0.0073 - val_loss: 0.0068
#
# Epoch 00063: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-63-0.00679.hdf5
# Epoch 64/100
# 58/58 [==============================] - 0s 825us/step - loss: 0.0071 - val_loss: 0.0046
#
# Epoch 00064: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-64-0.00463.hdf5
# Epoch 65/100
# 58/58 [==============================] - 0s 946us/step - loss: 0.0075 - val_loss: 0.0075
#
# Epoch 00065: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-65-0.00751.hdf5
# Epoch 66/100
# 58/58 [==============================] - 0s 894us/step - loss: 0.0066 - val_loss: 0.0073
#
# Epoch 00066: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-66-0.00727.hdf5
# Epoch 67/100
# 58/58 [==============================] - 0s 963us/step - loss: 0.0080 - val_loss: 0.0066
#
# Epoch 00067: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-67-0.00662.hdf5
# Epoch 68/100
# 58/58 [==============================] - 0s 963us/step - loss: 0.0064 - val_loss: 0.0055
#
# Epoch 00068: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-68-0.00547.hdf5
# Epoch 69/100
# 58/58 [==============================] - 0s 929us/step - loss: 0.0082 - val_loss: 0.0060
#
# Epoch 00069: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-69-0.00596.hdf5
# Epoch 70/100
# 58/58 [==============================] - 0s 946us/step - loss: 0.0056 - val_loss: 0.0104
#
# Epoch 00070: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-70-0.01040.hdf5
# Epoch 71/100
# 58/58 [==============================] - 0s 929us/step - loss: 0.0073 - val_loss: 0.0063
#
# Epoch 00071: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-71-0.00634.hdf5
# Epoch 72/100
# 58/58 [==============================] - 0s 929us/step - loss: 0.0055 - val_loss: 0.0042
#
# Epoch 00072: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-72-0.00422.hdf5
# Epoch 73/100
# 58/58 [==============================] - 0s 911us/step - loss: 0.0094 - val_loss: 0.0077
#
# Epoch 00073: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-73-0.00772.hdf5
# Epoch 74/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0081
#
# Epoch 00074: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-74-0.00809.hdf5
# Epoch 75/100
# 58/58 [==============================] - 0s 929us/step - loss: 0.0064 - val_loss: 0.0083
#
# Epoch 00075: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-75-0.00826.hdf5
# Epoch 76/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0070 - val_loss: 0.0051
#
# Epoch 00076: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-76-0.00513.hdf5
# Epoch 77/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0071
#
# Epoch 00077: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-77-0.00708.hdf5
# Epoch 78/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0067 - val_loss: 0.0063
#
# Epoch 00078: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-78-0.00632.hdf5
# Epoch 79/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0070 - val_loss: 0.0067
#
# Epoch 00079: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-79-0.00666.hdf5
# Epoch 80/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0034
#
# Epoch 00080: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-80-0.00339.hdf5
# Epoch 81/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0069 - val_loss: 0.0055
#
# Epoch 00081: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-81-0.00554.hdf5
# Epoch 82/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0072 - val_loss: 0.0093
#
# Epoch 00082: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-82-0.00925.hdf5
# Epoch 83/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0066 - val_loss: 0.0058
#
# Epoch 00083: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-83-0.00585.hdf5
# Epoch 84/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0060 - val_loss: 0.0051
#
# Epoch 00084: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-84-0.00511.hdf5
# Epoch 85/100
# 58/58 [==============================] - 0s 911us/step - loss: 0.0069 - val_loss: 0.0087
#
# Epoch 00085: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-85-0.00874.hdf5
# Epoch 86/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0058 - val_loss: 0.0058
#
# Epoch 00086: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-86-0.00584.hdf5
# Epoch 87/100
# 58/58 [==============================] - 0s 860us/step - loss: 0.0069 - val_loss: 0.0046
#
# Epoch 00087: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-87-0.00463.hdf5
# Epoch 88/100
# 58/58 [==============================] - 0s 946us/step - loss: 0.0064 - val_loss: 0.0042
#
# Epoch 00088: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-88-0.00417.hdf5
# Epoch 89/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0082
#
# Epoch 00089: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-89-0.00818.hdf5
# Epoch 90/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0076 - val_loss: 0.0048
#
# Epoch 00090: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-90-0.00481.hdf5
# Epoch 91/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0068 - val_loss: 0.0051
#
# Epoch 00091: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-91-0.00510.hdf5
# Epoch 92/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0086
#
# Epoch 00092: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-92-0.00859.hdf5
# Epoch 93/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0080 - val_loss: 0.0084
#
# Epoch 00093: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-93-0.00839.hdf5
# Epoch 94/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0059
#
# Epoch 00094: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-94-0.00595.hdf5
# Epoch 95/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0056
#
# Epoch 00095: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-95-0.00556.hdf5
# Epoch 96/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0065
#
# Epoch 00096: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-96-0.00646.hdf5
# Epoch 97/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0062
#
# Epoch 00097: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-97-0.00621.hdf5
# Epoch 98/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0066 - val_loss: 0.0071
#
# Epoch 00098: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-98-0.00706.hdf5
# Epoch 99/100
# 58/58 [==============================] - 0s 929us/step - loss: 0.0059 - val_loss: 0.0060
#
# Epoch 00099: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-99-0.00597.hdf5
# Epoch 100/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0074
#
# Epoch 00100: saving model to weights_paper/bitcoin2015to2019_close_CNN_2_relu-100-0.00736.hdf5
