# %%
import pandas as pd
import numpy as numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU, PReLU
from keras.utils import np_utils
from keras.callbacks import CSVLogger, ModelCheckpoint
import h5py
import os
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

# %%
# Use CNN to capture local temporal dependency of data in risk prediction or other related tasks.
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config))

# %%
with h5py.File(''.join(['bitcoin2016-12to2019-10_close.h5']), 'r') as hf:
    datas = hf['inputs'].value
    labels = hf['outputs'].value

# %%
datas.shape
# Out:
# (1101, 256, 1)

# %%
output_file_name='bitcoin2016-10to2019-10_close_CNN_2_relu'

# %%
step_size = datas.shape[1]
batch_size= 8
nb_features = datas.shape[2]

# %%
epochs = 100

# %%
#split training validation
training_size = int(0.8* datas.shape[0])
training_datas = datas[:training_size,:]
training_labels = labels[:training_size,:]
validation_datas = datas[training_size:,:]
validation_labels = labels[training_size:,:]

# %%
model = Sequential()
model.add(Conv1D(activation='relu',
input_shape=(step_size, nb_features), strides=3,
filters=8, kernel_size=8))
model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2,
filters=8, kernel_size=8))
model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(strides=2, filters=nb_features,
kernel_size=8))

# %%
model.compile(loss='mse', optimizer='adam')
model.fit(training_datas, training_labels, verbose=1, batch_size=batch_size, validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True), ModelCheckpoint('NewWeights/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])
# Out:
# Train on 880 samples, validate on 221 samples
# Epoch 1/100
# 880/880 [==============================] - 3s 3ms/step - loss: 0.0230 - val_loss: 0.0061
#
# Epoch 00001: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-01-0.00607.hdf5
# Epoch 2/100
# 880/880 [==============================] - 1s 870us/step - loss: 0.0082 - val_loss: 0.0022
#
# Epoch 00002: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-02-0.00215.hdf5
# Epoch 3/100
# 880/880 [==============================] - 1s 900us/step - loss: 0.0066 - val_loss: 0.0012
#
# Epoch 00003: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-03-0.00118.hdf5
# Epoch 4/100
# 880/880 [==============================] - 1s 913us/step - loss: 0.0059 - val_loss: 0.0011
#
# Epoch 00004: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-04-0.00111.hdf5
# Epoch 5/100
# 880/880 [==============================] - 1s 925us/step - loss: 0.0051 - val_loss: 1.8525e-04
#
# Epoch 00005: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-05-0.00019.hdf5
# Epoch 6/100
# 880/880 [==============================] - 1s 935us/step - loss: 0.0048 - val_loss: 0.0022
#
# Epoch 00006: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-06-0.00218.hdf5
# Epoch 7/100
# 880/880 [==============================] - 1s 937us/step - loss: 0.0051 - val_loss: 0.0010
#
# Epoch 00007: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-07-0.00102.hdf5
# Epoch 8/100
# 880/880 [==============================] - 1s 980us/step - loss: 0.0048 - val_loss: 2.6043e-04
#
# Epoch 00008: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-08-0.00026.hdf5
# Epoch 9/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0045 - val_loss: 0.0073
#
# Epoch 00009: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-09-0.00734.hdf5
# Epoch 10/100
# 880/880 [==============================] - 1s 897us/step - loss: 0.0044 - val_loss: 6.2892e-04
#
# Epoch 00010: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-10-0.00063.hdf5
# Epoch 11/100
# 880/880 [==============================] - 1s 963us/step - loss: 0.0044 - val_loss: 0.0056
#
# Epoch 00011: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-11-0.00558.hdf5
# Epoch 12/100
# 880/880 [==============================] - 1s 972us/step - loss: 0.0043 - val_loss: 8.3060e-04
#
# Epoch 00012: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-12-0.00083.hdf5
# Epoch 13/100
# 880/880 [==============================] - 1s 932us/step - loss: 0.0039 - val_loss: 1.9606e-04
#
# Epoch 00013: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-13-0.00020.hdf5
# Epoch 14/100
# 880/880 [==============================] - 1s 938us/step - loss: 0.0041 - val_loss: 1.9594e-04
#
# Epoch 00014: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-14-0.00020.hdf5
# Epoch 15/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0015
#
# Epoch 00015: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-15-0.00151.hdf5
# Epoch 16/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 0.0016
#
# Epoch 00016: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-16-0.00163.hdf5
# Epoch 17/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 3.7932e-04
#
# Epoch 00017: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-17-0.00038.hdf5
# Epoch 18/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0041 - val_loss: 4.1874e-04
#
# Epoch 00018: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-18-0.00042.hdf5
# Epoch 19/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 2.0379e-04
#
# Epoch 00019: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-19-0.00020.hdf5
# Epoch 20/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 0.0011
#
# Epoch 00020: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-20-0.00114.hdf5
# Epoch 21/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 0.0044
#
# Epoch 00021: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-21-0.00440.hdf5
# Epoch 22/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0040 - val_loss: 0.0014
#
# Epoch 00022: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-22-0.00143.hdf5
# Epoch 23/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 1.8461e-04
#
# Epoch 00023: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-23-0.00018.hdf5
# Epoch 24/100
# 880/880 [==============================] - 1s 961us/step - loss: 0.0038 - val_loss: 1.9037e-04
#
# Epoch 00024: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-24-0.00019.hdf5
# Epoch 25/100
# 880/880 [==============================] - 1s 947us/step - loss: 0.0040 - val_loss: 5.2919e-04
#
# Epoch 00025: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-25-0.00053.hdf5
# Epoch 26/100
# 880/880 [==============================] - 1s 952us/step - loss: 0.0038 - val_loss: 1.8389e-04
#
# Epoch 00026: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-26-0.00018.hdf5
# Epoch 27/100
# 880/880 [==============================] - 1s 998us/step - loss: 0.0038 - val_loss: 0.0011
#
# Epoch 00027: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-27-0.00105.hdf5
# Epoch 28/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 5.7559e-04
#
# Epoch 00028: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-28-0.00058.hdf5
# Epoch 29/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0041 - val_loss: 2.4224e-04
#
# Epoch 00029: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-29-0.00024.hdf5
# Epoch 30/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 2.7529e-04
#
# Epoch 00030: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-30-0.00028.hdf5
# Epoch 31/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0018
#
# Epoch 00031: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-31-0.00180.hdf5
# Epoch 32/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 4.6370e-04
#
# Epoch 00032: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-32-0.00046.hdf5
# Epoch 33/100
# 880/880 [==============================] - 1s 993us/step - loss: 0.0040 - val_loss: 0.0025
#
# Epoch 00033: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-33-0.00247.hdf5
# Epoch 34/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 3.2247e-04
#
# Epoch 00034: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-34-0.00032.hdf5
# Epoch 35/100
# 880/880 [==============================] - 1s 916us/step - loss: 0.0038 - val_loss: 2.4519e-04
#
# Epoch 00035: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-35-0.00025.hdf5
# Epoch 36/100
# 880/880 [==============================] - 1s 976us/step - loss: 0.0037 - val_loss: 0.0012
#
# Epoch 00036: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-36-0.00124.hdf5
# Epoch 37/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0039 - val_loss: 5.9479e-04
#
# Epoch 00037: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-37-0.00059.hdf5
# Epoch 38/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 2.0489e-04
#
# Epoch 00038: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-38-0.00020.hdf5
# Epoch 39/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0038 - val_loss: 2.1926e-04
#
# Epoch 00039: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-39-0.00022.hdf5
# Epoch 40/100
# 880/880 [==============================] - 1s 996us/step - loss: 0.0035 - val_loss: 6.7477e-04
#
# Epoch 00040: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-40-0.00067.hdf5
# Epoch 41/100
# 880/880 [==============================] - 1s 954us/step - loss: 0.0038 - val_loss: 0.0011
#
# Epoch 00041: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-41-0.00109.hdf5
# Epoch 42/100
# 880/880 [==============================] - 1s 907us/step - loss: 0.0037 - val_loss: 8.8681e-04
#
# Epoch 00042: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-42-0.00089.hdf5
# Epoch 43/100
# 880/880 [==============================] - 1s 937us/step - loss: 0.0036 - val_loss: 1.8675e-04
#
# Epoch 00043: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-43-0.00019.hdf5
# Epoch 44/100
# 880/880 [==============================] - 1s 914us/step - loss: 0.0035 - val_loss: 0.0011
#
# Epoch 00044: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-44-0.00110.hdf5
# Epoch 45/100
# 880/880 [==============================] - 1s 934us/step - loss: 0.0035 - val_loss: 5.6099e-04
#
# Epoch 00045: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-45-0.00056.hdf5
# Epoch 46/100
# 880/880 [==============================] - 1s 995us/step - loss: 0.0036 - val_loss: 4.3093e-04
#
# Epoch 00046: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-46-0.00043.hdf5
# Epoch 47/100
# 880/880 [==============================] - 1s 973us/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00047: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-47-0.00354.hdf5
# Epoch 48/100
# 880/880 [==============================] - 1s 984us/step - loss: 0.0036 - val_loss: 8.5150e-04
#
# Epoch 00048: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-48-0.00085.hdf5
# Epoch 49/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 0.0016
#
# Epoch 00049: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-49-0.00160.hdf5
# Epoch 50/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 0.0025
#
# Epoch 00050: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-50-0.00252.hdf5
# Epoch 51/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 8.0970e-04
#
# Epoch 00051: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-51-0.00081.hdf5
# Epoch 52/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 0.0040
#
# Epoch 00052: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-52-0.00396.hdf5
# Epoch 53/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 5.5775e-04
#
# Epoch 00053: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-53-0.00056.hdf5
# Epoch 54/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 0.0025
#
# Epoch 00054: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-54-0.00252.hdf5
# Epoch 55/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 4.8844e-04
#
# Epoch 00055: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-55-0.00049.hdf5
# Epoch 56/100
# 880/880 [==============================] - 1s 904us/step - loss: 0.0033 - val_loss: 0.0024
#
# Epoch 00056: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-56-0.00235.hdf5
# Epoch 57/100
# 880/880 [==============================] - 1s 934us/step - loss: 0.0031 - val_loss: 6.5415e-04
#
# Epoch 00057: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-57-0.00065.hdf5
# Epoch 58/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0033 - val_loss: 3.6301e-04
#
# Epoch 00058: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-58-0.00036.hdf5
# Epoch 59/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0033 - val_loss: 4.2413e-04
#
# Epoch 00059: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-59-0.00042.hdf5
# Epoch 60/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 5.1052e-04
#
# Epoch 00060: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-60-0.00051.hdf5
# Epoch 61/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 3.5207e-04
#
# Epoch 00061: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-61-0.00035.hdf5
# Epoch 62/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0033 - val_loss: 3.5988e-04
#
# Epoch 00062: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-62-0.00036.hdf5
# Epoch 63/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 0.0010
#
# Epoch 00063: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-63-0.00102.hdf5
# Epoch 64/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0030 - val_loss: 0.0021
#
# Epoch 00064: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-64-0.00209.hdf5
# Epoch 65/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 2.0011e-04
#
# Epoch 00065: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-65-0.00020.hdf5
# Epoch 66/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0030 - val_loss: 0.0011
#
# Epoch 00066: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-66-0.00107.hdf5
# Epoch 67/100
# 880/880 [==============================] - 1s 952us/step - loss: 0.0029 - val_loss: 0.0012
#
# Epoch 00067: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-67-0.00117.hdf5
# Epoch 68/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 1.9081e-04
#
# Epoch 00068: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-68-0.00019.hdf5
# Epoch 69/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0029 - val_loss: 4.0434e-04
#
# Epoch 00069: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-69-0.00040.hdf5
# Epoch 70/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0030 - val_loss: 0.0019
#
# Epoch 00070: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-70-0.00186.hdf5
# Epoch 71/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 1.8446e-04
#
# Epoch 00071: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-71-0.00018.hdf5
# Epoch 72/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0033 - val_loss: 0.0016
#
# Epoch 00072: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-72-0.00156.hdf5
# Epoch 73/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0034 - val_loss: 3.3385e-04
#
# Epoch 00073: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-73-0.00033.hdf5
# Epoch 74/100
# 880/880 [==============================] - 1s 905us/step - loss: 0.0031 - val_loss: 5.8480e-04
#
# Epoch 00074: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-74-0.00058.hdf5
# Epoch 75/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0033 - val_loss: 4.5790e-04
#
# Epoch 00075: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-75-0.00046.hdf5
# Epoch 76/100
# 880/880 [==============================] - 1s 985us/step - loss: 0.0033 - val_loss: 3.3497e-04
#
# Epoch 00076: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-76-0.00033.hdf5
# Epoch 77/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0030 - val_loss: 0.0019
#
# Epoch 00077: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-77-0.00189.hdf5
# Epoch 78/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0030 - val_loss: 0.0044
#
# Epoch 00078: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-78-0.00437.hdf5
# Epoch 79/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0030 - val_loss: 9.1739e-04
#
# Epoch 00079: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-79-0.00092.hdf5
# Epoch 80/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 3.6450e-04
#
# Epoch 00080: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-80-0.00036.hdf5
# Epoch 81/100
# 880/880 [==============================] - 1s 984us/step - loss: 0.0031 - val_loss: 1.7538e-04
# Epoch 00081: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-81-0.00018.hdf5
# Epoch 82/100
# 880/880 [==============================] - 1s 976us/step - loss: 0.0032 - val_loss: 2.0563e-04
#
# Epoch 00082: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-82-0.00021.hdf5
# Epoch 83/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 2.3467e-04
#
# Epoch 00083: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-83-0.00023.hdf5
# Epoch 84/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 2.2877e-04
#
# Epoch 00084: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-84-0.00023.hdf5
# Epoch 85/100
# 880/880 [==============================] - 1s 955us/step - loss: 0.0029 - val_loss: 3.4660e-04
#
# Epoch 00085: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-85-0.00035.hdf5
# Epoch 86/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 1.7530e-04
#
# Epoch 00086: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-86-0.00018.hdf5
# Epoch 87/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0030 - val_loss: 3.5087e-04
#
# Epoch 00087: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-87-0.00035.hdf5
# Epoch 88/100
# 880/880 [==============================] - 1s 936us/step - loss: 0.0030 - val_loss: 0.0014
#
# Epoch 00088: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-88-0.00137.hdf5
# Epoch 89/100
# 880/880 [==============================] - 1s 979us/step - loss: 0.0029 - val_loss: 0.0026
#
# Epoch 00089: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-89-0.00262.hdf5
# Epoch 90/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 4.4113e-04
#
# Epoch 00090: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-90-0.00044.hdf5
# Epoch 91/100
# 880/880 [==============================] - 1s 936us/step - loss: 0.0031 - val_loss: 4.1461e-04
#
# Epoch 00091: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-91-0.00041.hdf5
# Epoch 92/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0033 - val_loss: 3.4612e-04
#
# Epoch 00092: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-92-0.00035.hdf5
# Epoch 93/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 6.6747e-04
#
# Epoch 00093: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-93-0.00067.hdf5
# Epoch 94/100
# 880/880 [==============================] - 1s 950us/step - loss: 0.0031 - val_loss: 4.9252e-04
#
# Epoch 00094: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-94-0.00049.hdf5
# Epoch 95/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0030 - val_loss: 9.0233e-04
#
# Epoch 00095: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-95-0.00090.hdf5
# Epoch 96/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0029 - val_loss: 1.8283e-04
#
# Epoch 00096: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-96-0.00018.hdf5
# Epoch 97/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0028 - val_loss: 2.1795e-04
#
# Epoch 00097: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-97-0.00022.hdf5
# Epoch 98/100
# 880/880 [==============================] - 1s 954us/step - loss: 0.0030 - val_loss: 1.9377e-04
#
# Epoch 00098: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-98-0.00019.hdf5
# Epoch 99/100
# 880/880 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 8.9081e-04
#
# Epoch 00099: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-99-0.00089.hdf5
# Epoch 100/100
# 880/880 [==============================] - 1s 955us/step - loss: 0.0028 - val_loss: 0.0019
#
# Epoch 00100: saving model to NewWeights/bitcoin2016-10to2019-10_close_CNN_2_relu-100-0.00188.hdf5
