# %%
import pandas as pd
import numpy as numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU, PReLU
from keras.utils import np_utils
from keras.callbacks import CSVLogger, ModelCheckpoint
import h5py
import os
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
# Out:
# Using TensorFlow backend.

# %%
# Use CNN to capture local temporal dependency of data in risk prediction or other related tasks.
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config))

# %%
with h5py.File(''.join(['bitcoin2015to2019_close.h5']), 'r') as hf:
    datas = hf['inputs'].value
    labels = hf['outputs'].value

# %%
output_file_name='bitcoin2015to2019_close_CNN_2_relu'

# %%
step_size = datas.shape[1]
batch_size= 8
nb_features = datas.shape[2]

# %%
epochs = 100

# %%
#split training validation
training_size = int(0.8* datas.shape[0])
training_datas = datas[:training_size,:]
training_labels = labels[:training_size,:]
validation_datas = datas[training_size:,:]
validation_labels = labels[training_size:,:]

# %%
model = Sequential()
model.add(Conv1D(activation='relu',
input_shape=(step_size, nb_features), strides=3,
filters=8, kernel_size=8))
model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2,
filters=8, kernel_size=8))
model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(strides=2, filters=nb_features,
kernel_size=8))

# %%
model.compile(loss='mse', optimizer='adam')
model.fit(training_datas, training_labels, verbose=1, batch_size=batch_size, validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True), ModelCheckpoint('weights/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])
# Out:
# W1019 21:39:58.343137 15144 deprecation_wrapper.py:119] From C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 58 samples, validate on 15 samples
# Epoch 1/100
# 58/58 [==============================] - 3s 53ms/step - loss: 0.0860 - val_loss: 0.0954
#
# Epoch 00001: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-01-0.09536.hdf5
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-32-3ad2accc7640> in <module>
#       1 model.compile(loss='mse', optimizer='adam')
# ----> 2 model.fit(training_datas, training_labels, verbose=1, batch_size=batch_size, validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True), ModelCheckpoint('weights/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])
#
# C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     215                         for l, o in zip(out_labels, val_outs):
#     216                             epoch_logs['val_' + l] = o
# --> 217         callbacks.on_epoch_end(epoch, epoch_logs)
#     218         if callback_model.stop_training:
#     219             break
#
# C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#      77         logs = logs or {}
#      78         for callback in self.callbacks:
# ---> 79             callback.on_epoch_end(epoch, logs)
#      80
#      81     def on_batch_begin(self, batch, logs=None):
#
# C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     455                     self.model.save_weights(filepath, overwrite=True)
#     456                 else:
# --> 457                     self.model.save(filepath, overwrite=True)
#     458
#     459
#
# C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\engine\network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\engine\saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     377         opened_new_file = False
#     378
# --> 379     f = h5dict(filepath, mode='w')
#     380
#     381     try:
#
# C:\Anaconda3\envs\deep-learning\lib\site-packages\keras\utils\io_utils.py in __init__(self, path, mode)
#     184             self._is_file = False
#     185         elif isinstance(path, str):
# --> 186             self.data = h5py.File(path, mode=mode)
#     187             self._is_file = True
#     188         elif isinstance(path, dict):
#
# C:\Anaconda3\envs\deep-learning\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     310             with phil:
#     311                 fapl = make_fapl(driver, libver, **kwds)
# --> 312                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     313
#     314                 if swmr_support:
#
# C:\Anaconda3\envs\deep-learning\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     146         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     147     elif mode == 'w':
# --> 148         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     149     elif mode == 'a':
#     150         # Open in append mode (read/write).
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = 'weights/bitcoin2015to2019_close_CNN_2_relu-01-0.09536.hdf5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 302)

# %%
#build model

# 2 layers
model = Sequential()


model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=3, filters=8, kernel_size=20))
#model.add(PReLU())
model.add(Dropout(0.5))
model.add(Conv1D( strides=4, filters=nb_features, kernel_size=16))

'''
# 3 Layers
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=3, filters=8, kernel_size=8))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=8))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D( strides=2, filters=nb_features, kernel_size=8))
# 4 layers
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D( strides=2, filters=nb_features, kernel_size=2))
'''

model.compile(loss='mse', optimizer='adam')
model.fit(training_datas, training_labels, verbose=1, batch_size=batch_size, validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True), ModelCheckpoint('weights/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])

#model.fit(datas,labels)
#model.save(output_file_name+'.h5')
# Out:
# Train on 58 samples, validate on 15 samples
# Epoch 1/100
# 58/58 [==============================] - 1s 19ms/step - loss: 0.1942 - val_loss: 0.2355
#
# Epoch 00001: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-01-0.23547.hdf5
# Epoch 2/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.1135 - val_loss: 0.0882
#
# Epoch 00002: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-02-0.08825.hdf5
# Epoch 3/100
# 58/58 [==============================] - 0s 843us/step - loss: 0.0478 - val_loss: 0.0239
#
# Epoch 00003: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-03-0.02389.hdf5
# Epoch 4/100
# 58/58 [==============================] - 0s 877us/step - loss: 0.0374 - val_loss: 0.0049
#
# Epoch 00004: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-04-0.00488.hdf5
# Epoch 5/100
# 58/58 [==============================] - 0s 922us/step - loss: 0.0286 - val_loss: 0.0032
#
# Epoch 00005: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-05-0.00320.hdf5
# Epoch 6/100
# 58/58 [==============================] - 0s 929us/step - loss: 0.0216 - val_loss: 0.0033
#
# Epoch 00006: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-06-0.00331.hdf5
# Epoch 7/100
# 58/58 [==============================] - 0s 878us/step - loss: 0.0194 - val_loss: 0.0047
#
# Epoch 00007: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-07-0.00465.hdf5
# Epoch 8/100
# 58/58 [==============================] - 0s 997us/step - loss: 0.0131 - val_loss: 0.0073
#
# Epoch 00008: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-08-0.00726.hdf5
# Epoch 9/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0151 - val_loss: 0.0083
#
# Epoch 00009: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-09-0.00826.hdf5
# Epoch 10/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0069
#
# Epoch 00010: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-10-0.00690.hdf5
# Epoch 11/100
# 58/58 [==============================] - 0s 911us/step - loss: 0.0092 - val_loss: 0.0059
#
# Epoch 00011: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-11-0.00593.hdf5
# Epoch 12/100
# 58/58 [==============================] - 0s 756us/step - loss: 0.0091 - val_loss: 0.0038
#
# Epoch 00012: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-12-0.00384.hdf5
# Epoch 13/100
# 58/58 [==============================] - 0s 929us/step - loss: 0.0076 - val_loss: 0.0036
#
# Epoch 00013: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-13-0.00357.hdf5
# Epoch 14/100
# 58/58 [==============================] - 0s 877us/step - loss: 0.0095 - val_loss: 0.0046
#
# Epoch 00014: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-14-0.00462.hdf5
# Epoch 15/100
# 58/58 [==============================] - 0s 998us/step - loss: 0.0073 - val_loss: 0.0047
#
# Epoch 00015: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-15-0.00474.hdf5
# Epoch 16/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0054
#
# Epoch 00016: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-16-0.00541.hdf5
# Epoch 17/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0078
#
# Epoch 00017: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-17-0.00782.hdf5
# Epoch 18/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0107
#
# Epoch 00018: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-18-0.01072.hdf5
# Epoch 19/100
# 58/58 [==============================] - 0s 860us/step - loss: 0.0079 - val_loss: 0.0063
#
# Epoch 00019: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-19-0.00627.hdf5
# Epoch 20/100
# 58/58 [==============================] - 0s 825us/step - loss: 0.0060 - val_loss: 0.0032
#
# Epoch 00020: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-20-0.00319.hdf5
# Epoch 21/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0068 - val_loss: 0.0042
#
# Epoch 00021: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-21-0.00425.hdf5
# Epoch 22/100
# 58/58 [==============================] - 0s 860us/step - loss: 0.0067 - val_loss: 0.0066
#
# Epoch 00022: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-22-0.00660.hdf5
# Epoch 23/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0072 - val_loss: 0.0054
#
# Epoch 00023: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-23-0.00544.hdf5
# Epoch 24/100
# 58/58 [==============================] - 0s 911us/step - loss: 0.0051 - val_loss: 0.0053
#
# Epoch 00024: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-24-0.00531.hdf5
# Epoch 25/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0051 - val_loss: 0.0050
#
# Epoch 00025: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-25-0.00502.hdf5
# Epoch 26/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0043
#
# Epoch 00026: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-26-0.00434.hdf5
# Epoch 27/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0041
#
# Epoch 00027: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-27-0.00411.hdf5
# Epoch 28/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0039
#
# Epoch 00028: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-28-0.00389.hdf5
# Epoch 29/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0033
#
# Epoch 00029: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-29-0.00335.hdf5
# Epoch 30/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0051
#
# Epoch 00030: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-30-0.00506.hdf5
# Epoch 31/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0054
#
# Epoch 00031: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-31-0.00538.hdf5
# Epoch 32/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0046 - val_loss: 0.0042
#
# Epoch 00032: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-32-0.00422.hdf5
# Epoch 33/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00033: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-33-0.00408.hdf5
# Epoch 34/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0050 - val_loss: 0.0052
#
# Epoch 00034: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-34-0.00519.hdf5
# Epoch 35/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0057
#
# Epoch 00035: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-35-0.00566.hdf5
# Epoch 36/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0059 - val_loss: 0.0049
#
# Epoch 00036: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-36-0.00489.hdf5
# Epoch 37/100
# 58/58 [==============================] - 0s 963us/step - loss: 0.0049 - val_loss: 0.0038
#
# Epoch 00037: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-37-0.00382.hdf5
# Epoch 38/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0034
#
# Epoch 00038: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-38-0.00341.hdf5
# Epoch 39/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0045
#
# Epoch 00039: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-39-0.00448.hdf5
# Epoch 40/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0034
#
# Epoch 00040: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-40-0.00341.hdf5
# Epoch 41/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0059
#
# Epoch 00041: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-41-0.00592.hdf5
# Epoch 42/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0077
#
# Epoch 00042: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-42-0.00774.hdf5
# Epoch 43/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0045
#
# Epoch 00043: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-43-0.00448.hdf5
# Epoch 44/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0046 - val_loss: 0.0035
#
# Epoch 00044: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-44-0.00352.hdf5
# Epoch 45/100
# 58/58 [==============================] - 0s 894us/step - loss: 0.0041 - val_loss: 0.0034
#
# Epoch 00045: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-45-0.00337.hdf5
# Epoch 46/100
# 58/58 [==============================] - 0s 825us/step - loss: 0.0040 - val_loss: 0.0038
#
# Epoch 00046: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-46-0.00383.hdf5
# Epoch 47/100
# 58/58 [==============================] - 0s 860us/step - loss: 0.0042 - val_loss: 0.0052
#
# Epoch 00047: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-47-0.00519.hdf5
# Epoch 48/100
# 58/58 [==============================] - 0s 823us/step - loss: 0.0039 - val_loss: 0.0032
#
# Epoch 00048: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-48-0.00316.hdf5
# Epoch 49/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0052
#
# Epoch 00049: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-49-0.00523.hdf5
# Epoch 50/100
# 58/58 [==============================] - 0s 946us/step - loss: 0.0045 - val_loss: 0.0045
#
# Epoch 00050: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-50-0.00453.hdf5
# Epoch 51/100
# 58/58 [==============================] - 0s 998us/step - loss: 0.0040 - val_loss: 0.0042
#
# Epoch 00051: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-51-0.00418.hdf5
# Epoch 52/100
# 58/58 [==============================] - 0s 843us/step - loss: 0.0050 - val_loss: 0.0089
#
# Epoch 00052: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-52-0.00892.hdf5
# Epoch 53/100
# 58/58 [==============================] - 0s 825us/step - loss: 0.0042 - val_loss: 0.0034
#
# Epoch 00053: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-53-0.00342.hdf5
# Epoch 54/100
# 58/58 [==============================] - 0s 963us/step - loss: 0.0042 - val_loss: 0.0033
#
# Epoch 00054: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-54-0.00334.hdf5
# Epoch 55/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0047 - val_loss: 0.0071
#
# Epoch 00055: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-55-0.00705.hdf5
# Epoch 56/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00056: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-56-0.00403.hdf5
# Epoch 57/100
# 58/58 [==============================] - 0s 791us/step - loss: 0.0039 - val_loss: 0.0035
#
# Epoch 00057: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-57-0.00345.hdf5
# Epoch 58/100
# 58/58 [==============================] - 0s 804us/step - loss: 0.0040 - val_loss: 0.0045
#
# Epoch 00058: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-58-0.00447.hdf5
# Epoch 59/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0050 - val_loss: 0.0055
#
# Epoch 00059: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-59-0.00551.hdf5
# Epoch 60/100
# 58/58 [==============================] - 0s 825us/step - loss: 0.0039 - val_loss: 0.0035
#
# Epoch 00060: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-60-0.00348.hdf5
# Epoch 61/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 0.0032
#
# Epoch 00061: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-61-0.00321.hdf5
# Epoch 62/100
# 58/58 [==============================] - 0s 821us/step - loss: 0.0052 - val_loss: 0.0043
#
# Epoch 00062: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-62-0.00428.hdf5
# Epoch 63/100
# 58/58 [==============================] - 0s 791us/step - loss: 0.0045 - val_loss: 0.0046
#
# Epoch 00063: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-63-0.00456.hdf5
# Epoch 64/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0059
#
# Epoch 00064: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-64-0.00592.hdf5
# Epoch 65/100
# 58/58 [==============================] - 0s 884us/step - loss: 0.0031 - val_loss: 0.0041
#
# Epoch 00065: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-65-0.00415.hdf5
# Epoch 66/100
# 58/58 [==============================] - 0s 705us/step - loss: 0.0037 - val_loss: 0.0034
#
# Epoch 00066: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-66-0.00342.hdf5
# Epoch 67/100
# 58/58 [==============================] - 0s 929us/step - loss: 0.0046 - val_loss: 0.0040
#
# Epoch 00067: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-67-0.00403.hdf5
# Epoch 68/100
# 58/58 [==============================] - 0s 914us/step - loss: 0.0037 - val_loss: 0.0042
#
# Epoch 00068: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-68-0.00417.hdf5
# Epoch 69/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0032
#
# Epoch 00069: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-69-0.00318.hdf5
# Epoch 70/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0033
#
# Epoch 00070: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-70-0.00332.hdf5
# Epoch 71/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0079
#
# Epoch 00071: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-71-0.00792.hdf5
# Epoch 72/100
# 58/58 [==============================] - 0s 894us/step - loss: 0.0043 - val_loss: 0.0043
#
# Epoch 00072: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-72-0.00427.hdf5
# Epoch 73/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0048 - val_loss: 0.0032
#
# Epoch 00073: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-73-0.00317.hdf5
# Epoch 74/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0064
#
# Epoch 00074: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-74-0.00639.hdf5
# Epoch 75/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0039
#
# Epoch 00075: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-75-0.00395.hdf5
# Epoch 76/100
# 58/58 [==============================] - 0s 894us/step - loss: 0.0035 - val_loss: 0.0038
#
# Epoch 00076: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-76-0.00380.hdf5
# Epoch 77/100
# 58/58 [==============================] - 0s 757us/step - loss: 0.0044 - val_loss: 0.0036
#
# Epoch 00077: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-77-0.00356.hdf5
# Epoch 78/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0033
#
# Epoch 00078: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-78-0.00329.hdf5
# Epoch 79/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0038
#
# Epoch 00079: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-79-0.00385.hdf5
# Epoch 80/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0042
#
# Epoch 00080: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-80-0.00417.hdf5
# Epoch 81/100
# 58/58 [==============================] - 0s 792us/step - loss: 0.0042 - val_loss: 0.0040
#
# Epoch 00081: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-81-0.00398.hdf5
# Epoch 82/100
# 58/58 [==============================] - 0s 911us/step - loss: 0.0047 - val_loss: 0.0030
#
# Epoch 00082: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-82-0.00296.hdf5
# Epoch 83/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00083: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-83-0.00409.hdf5
# Epoch 84/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0046
#
# Epoch 00084: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-84-0.00457.hdf5
# Epoch 85/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0033
#
# Epoch 00085: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-85-0.00328.hdf5
# Epoch 86/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0031
#
# Epoch 00086: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-86-0.00314.hdf5
# Epoch 87/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0063
#
# Epoch 00087: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-87-0.00629.hdf5
# Epoch 88/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0047
#
# Epoch 00088: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-88-0.00475.hdf5
# Epoch 89/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0048
#
# Epoch 00089: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-89-0.00477.hdf5
# Epoch 90/100
# 58/58 [==============================] - 0s 860us/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00090: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-90-0.00326.hdf5
# Epoch 91/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0077
#
# Epoch 00091: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-91-0.00770.hdf5
# Epoch 92/100
# 58/58 [==============================] - 0s 980us/step - loss: 0.0038 - val_loss: 0.0047
#
# Epoch 00092: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-92-0.00473.hdf5
# Epoch 93/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0031
#
# Epoch 00093: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-93-0.00308.hdf5
# Epoch 94/100
# 58/58 [==============================] - 0s 711us/step - loss: 0.0035 - val_loss: 0.0031
#
# Epoch 00094: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-94-0.00311.hdf5
# Epoch 95/100
# 58/58 [==============================] - 0s 791us/step - loss: 0.0032 - val_loss: 0.0044
#
# Epoch 00095: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-95-0.00440.hdf5
# Epoch 96/100
# 58/58 [==============================] - 0s 843us/step - loss: 0.0037 - val_loss: 0.0052
#
# Epoch 00096: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-96-0.00519.hdf5
# Epoch 97/100
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 0.0030
#
# Epoch 00097: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-97-0.00304.hdf5
# Epoch 98/100
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0044
#
# Epoch 00098: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-98-0.00439.hdf5
# Epoch 99/100
# 58/58 [==============================] - 0s 877us/step - loss: 0.0042 - val_loss: 0.0045
#
# Epoch 00099: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-99-0.00446.hdf5
# Epoch 100/100
# 58/58 [==============================] - 0s 877us/step - loss: 0.0033 - val_loss: 0.0036
#
# Epoch 00100: saving model to weights/bitcoin2015to2019_close_CNN_2_relu-100-0.00355.hdf5
